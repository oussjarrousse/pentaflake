# %%
import math
from random import randint, sample
from src.pentagon import PentaflakePentagon
from src.pentaflake import Pentaflake
from IPython.display import SVG

# %%
config={
    "draw-tiles":True, 
    "width": 400,
    "height": 400,
    "tile-opacity": 1,
    "random-tile-colors": True,
}

# %%
pentaflake = Pentaflake(origin=complex(200,200), circumradius=200)

# %%
def indices_sequence():
    counter=0
    while True:
        index = counter%5
        yield [index, index+1%5]
        counter+=1
        # if counter==6:
        #     counter = 0

# %%
def random_indices(n):
    while True:
        indices = sample(range(0,5),n )
        yield indices

# %%
gen = random_indices(3)
sorted(next(gen), reverse=True)
# Out:
# [3, 2, 0]

# %%
SVG(pentaflake.make_tiling(3, remove_inflated_tiles_indices=None).make_svg(config=config))

# %%
SVG(pentaflake.make_tiling(3, remove_inflated_tiles_indices=[0]).make_svg(config=config))

# %%
math.phi
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-3db2d4560b3b> in <module>
# ----> 1 math.phi
#
# AttributeError: module 'math' has no attribute 'phi'
